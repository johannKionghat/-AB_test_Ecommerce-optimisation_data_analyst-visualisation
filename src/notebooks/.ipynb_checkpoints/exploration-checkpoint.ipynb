# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
events= pd.read_csv('../data/events.csv')
events
# Out:
#              timestamp  visitorid event  itemid  transactionid
# 0        1433221332117     257597  view  355908            NaN
# 1        1433224214164     992329  view  248676            NaN
# 2        1433221999827     111016  view  318965            NaN
# 3        1433221955914     483717  view  253185            NaN
# 4        1433221337106     951259  view  367447            NaN
# ...                ...        ...   ...     ...            ...
# 2756096  1438398785939     591435  view  261427            NaN
# 2756097  1438399813142     762376  view  115946            NaN
# 2756098  1438397820527    1251746  view   78144            NaN
# 2756099  1438398530703    1184451  view  283392            NaN
# 2756100  1438400163914     199536  view  152913            NaN
#
# [2756101 rows x 5 columns]

# %%
events_view=events[events['event']=="view"]
events_addtocart=events[events['event']=="addtocart"]
events_view
# Out:
#              timestamp  visitorid event  itemid  transactionid
# 0        1433221332117     257597  view  355908            NaN
# 1        1433224214164     992329  view  248676            NaN
# 2        1433221999827     111016  view  318965            NaN
# 3        1433221955914     483717  view  253185            NaN
# 4        1433221337106     951259  view  367447            NaN
# ...                ...        ...   ...     ...            ...
# 2756096  1438398785939     591435  view  261427            NaN
# 2756097  1438399813142     762376  view  115946            NaN
# 2756098  1438397820527    1251746  view   78144            NaN
# 2756099  1438398530703    1184451  view  283392            NaN
# 2756100  1438400163914     199536  view  152913            NaN
#
# [2664312 rows x 5 columns]

# %%
events_addtocart
# Out:
#              timestamp  visitorid      event  itemid  transactionid
# 17       1433223236124     287857  addtocart    5206            NaN
# 19       1433221078505     158090  addtocart   10572            NaN
# 63       1433223543021    1193904  addtocart  255275            NaN
# 112      1433221941632     599528  addtocart  356475            NaN
# 179      1433220880956     105775  addtocart  312728            NaN
# ...                ...        ...        ...     ...            ...
# 2755956  1438400400805     831605  addtocart   57810            NaN
# 2756056  1438398156086      10670  addtocart  419736            NaN
# 2756074  1438400994744     144106  addtocart  141241            NaN
# 2756078  1438399807937     804736  addtocart  447661            NaN
# 2756090  1438399811281     804736  addtocart  346534            NaN
#
# [69332 rows x 5 columns]

# %%
data = np.array([5, 15, 22, 28, 50, 75, 60, 52, 40, 90, 100, 150, 900])

mean = np.mean(data)
std_dev = np.std(data)

z_scores = (data - mean) / std_dev

# Identification des outliers
outliers = data[np.abs(z_scores) > 3]

print(f"Z-scores : {z_scores}")
print(f"Valeurs aberrantes : {outliers}")
# Out:
# Z-scores : [-0.51402078 -0.47011625 -0.43938307 -0.41304035 -0.31645038 -0.20668904
#  -0.27254584 -0.30766947 -0.36035491 -0.14083224 -0.0969277   0.12259497
#   3.41543507]
# Valeurs aberrantes : [900]

# %%
test= events["itemid"]
test
# Out:
# 0          355908
# 1          248676
# 2          318965
# 3          253185
# 4          367447
#             ...
# 2756096    261427
# 2756097    115946
# 2756098     78144
# 2756099    283392
# 2756100    152913
# Name: itemid, Length: 2756101, dtype: int64

# %%
testmean = np.mean(test) 
teststd = np.std(test)
z_scores = (test - testmean) / teststd
outliers = test[np.abs(z_scores) > 3]

print(f"Z-scores : {z_scores}")
print(f"Valeurs aberrantes : {outliers}")
# Out:
# Z-scores : 0          0.901562
# 1          0.102489
# 2          0.626270
# 3          0.136089
# 4          0.987549
#              ...
# 2756096    0.197507
# 2756097   -0.886591
# 2756098   -1.168285
# 2756099    0.361186
# 2756100   -0.611120
# Name: itemid, Length: 2756101, dtype: float64
# Valeurs aberrantes : Series([], Name: itemid, dtype: int64)

# %%
sns.countplot(x='event', data=events)
plt.title("Répartition des événements")
plt.xlabel("Type d'événement")
plt.ylabel("Nombre d'événements")
plt.show()

# %%
# Calcul des valeurs de 'event' pour créer un graphique circulaire
event_counts = events['event'].value_counts()
labels = event_counts.index
sizes = event_counts.values

# Explosion de la deuxième et troisième tranche pour mettre en évidence
explode = (0, 0.15, 0.15)  # Explose les tranches pour mettre en évidence

# Création d'une figure pour le graphique en camembert
plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)

# Assurer un aspect circulaire
plt.axis('equal')

# Affichage du graphique
plt.title("Répartition des événements (Camembert)")
plt.show()
